# %%
import os
import sys

cwd = os.getcwd()
print(f"Current working directory: {cwd}")
print(f"\nsys.path:")
for p in sys.path:
    print(f"  {p}")

# Check if cwd matches sync directory
sync_dir = next((p for p in sys.path if 'jupyter_databricks_kernel' in p), None)
print(f"\nExpected sync_dir: {sync_dir}")
print(f"cwd == sync_dir: {cwd == sync_dir}")

# %%
# Test relative path from notebooks directory
import os

# This should work if cwd is set to sync directory
print("Files in current directory:")
for f in os.listdir('.'):
    print(f"  {f}")

print("\nFiles in src/ (if exists):")
if os.path.exists('src'):
    for f in os.listdir('src'):
        print(f"  {f}")
else:
    print("  src/ not found")
