# %%
# Test 1: input() function
# Expected: StdinNotImplementedError
name = input("Enter your name: ")
print(f"Hello, {name}!")

# %%
# Test 2: ipywidgets
# Expected: Widget displays as text representation only, not interactive
import ipywidgets as widgets
from IPython.display import display

slider = widgets.IntSlider(value=50, min=0, max=100, description='Value:')
display(slider)
